# %% [markdown]
# The following steps need to be carried out in order to pre-process the data for topic modelling or any type of text/sentiment/topic-modelling analysis
#
#
# 1. Convert all text to lowercase
# 2. Remove URLs, twitter handles, punctuations and remove punctuations
# 3. Remove stopwords
# 4. Lemmatization (No stemming, why?, eg. computer becomes comput)
#
# The idea is to perform all of this using Spark or Python.
#
# This notebook does this on the twitter data and instagram data.

# %%
import sys
import findspark
from pyspark.sql import SparkSession

findspark.init()

spark = SparkSession.builder.appName('example application').getOrCreate()
assert sys.version_info >= (3, 4) # make sure we have Python 3.4+
assert spark.version >= '2.2' # make sure we have Spark 2.2+

# %% [markdown]
# Clean Twitter data

# %%
from pyspark.sql.types import StructField, StructType, StringType, ArrayType, IntegerType
from pyspark.sql.functions import lower, col, udf
from pyspark.sql import Row
from nltk.corpus import stopwords
import nltk
from os import listdir
from os.path import isfile, join
import json
import re

twitter_words = ['https','co','com','twitter','rt']

extended_stopwords = [word.strip() for word in open('g10000.txt')]

fields = ['screen_name', 'tweet_text', 'hashtags', 'favorites', 'retweet_count']
schema =  StructType([
    StructField('screen_name', StringType(), True),
    StructField('tweet_text', StringType(), True),
    StructField('hashtags', ArrayType(StringType()), True),
    StructField('favorites', IntegerType(), True),
    StructField('retweet_count', IntegerType(), True),
])

# Function to do the following things: Strips off URLs, punctuations, 
# User Names and Any non alphanumeric characters.
# Separates words with a single space.

def clean_tweets(text):
    cleaned = re.sub("(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", text).split()
    cleaned_ws = [word for word in cleaned if word not in stopwords and word not in twitter_words \
                 and word not in extended_stopwords]
    cleaned_wl = [lemma.lemmatize(word) for word in cleaned_ws]
    
    cleaned_wl = ' '.join(cleaned_ws)    
    return cleaned_wl.strip()

stopwords = stopwords.words('english')
lemma = nltk.wordnet.WordNetLemmatizer()

cleaner = udf(clean_tweets, StringType())

path = 'twitter-data'
twitter_files = [f for f in listdir(path) if isfile(join(path, f)) and (not f.startswith('.'))]

for twitter_file in twitter_files:    
    df = spark.read.json('twitter-data/{}'.format(twitter_file), schema=schema)
    tweet_df = df.select(lower(col('tweet_text')).alias('tweet_text_lower'))
    tweet_df_cleaned = tweet_df.select(cleaner('tweet_text_lower').alias('cleaned_tweet'))

    op_file_name = 'twitter-data/cleaned-ext/{}'.format(twitter_file)
    tweet_df_cleaned.write.text(op_file_name)

# %% [markdown]
# Clean Instagram Data

# %%
from nltk.corpus import stopwords

instagram_words = ['instagram', 'ig', 'https', 'http', 'tbt'] #Need to add more if required

extended_stopwords = [word.strip() for word in open('g10000.txt')]

fields = ['twitter_handle', 'instagram_handle', 'likes', 'comments',
         'hashtags', 'caption', 'timestamp', 'image_thumbnail']

schema =  StructType([
    StructField('twitter_handle', StringType(), True),
    StructField('instagram_handle', StringType(), True),
    StructField('likes', IntegerType(), True),
    StructField('comments', IntegerType(), True),
    StructField('hashtags', ArrayType(StringType()), True),
    StructField('caption', StringType(), True),
    StructField('timestamp', StringType(), True),
    StructField('image_thumbnail', StringType(), True),
])

def clean_captions(text):
    if text:
        cleaned = re.sub("(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", text).split()
        cleaned_ws = [word for word in cleaned if word not in stopwords and word not in instagram_words \
                     and not word in extended_stopwords]
        cleaned_wl = [lemma.lemmatize(word) for word in cleaned_ws]

        cleaned_wl = ' '.join(cleaned_ws) 
        return cleaned_wl.strip()
    else:
        return None
    
stopwords = stopwords.words('english')
lemma = nltk.wordnet.WordNetLemmatizer()

cleaner = udf(clean_captions, StringType())

path = 'instagram-data'
instagram_files = [f for f in listdir(path) if isfile(join(path, f)) and (not f.startswith('.'))]

for instagram_file in instagram_files:
    print('Working on file: {}'.format(instagram_file))
    df = spark.read.json('instagram-data/{}'.format(instagram_file), schema=schema)
    ig_df = df.select(lower(col('caption')).alias('caption_lower'))
    ig_df_cleaned = ig_df.select(cleaner('caption_lower').alias('cleaned_caption'))

    op_file_name = 'instagram-data/cleaned-ext/{}'.format(instagram_file)
    ig_df_cleaned.write.text(op_file_name)

# %% [markdown]
# Clean Facebook data

# %%
from nltk.corpus import stopwords

facebook_words = ['facebook', 'fb', 'https', 'http'] #Need to add more if required
fields = ['twitter_handle', 'fb_handle', 'fb_name', 'fb_no_of_comments',
         'fb_time_created', 'fb_description', 'fb_post_link', 'fb_img_link'
         'fb_shares', 'fb_type']

schema =  StructType([
    StructField('twitter_handle', StringType(), True),
    StructField('fb_handle', StringType(), True),
    StructField('fb_name', StringType(), True),
    StructField('fb_no_of_comments', IntegerType(), True),
    StructField('fb_time_created', StringType(), True),
    StructField('fb_description', StringType(), True),
    StructField('fb_post_link', StringType(), True),
    StructField('fb_img_link', StringType(), True),
    StructField('fb_shares', IntegerType(), True),
    StructField('fb_type', StringType(), True),
])

def clean_description(text):
    if text:
        cleaned = re.sub("(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", text).split()
        cleaned_ws = [word for word in cleaned if word not in stopwords and word not in facebook_words \
                     and word not in extended_stopwords]
        cleaned_wl = [lemma.lemmatize(word) for word in cleaned_ws]

        cleaned_wl = ' '.join(cleaned_ws) 
        return cleaned_wl.strip()
    else:
        return None
    
stopwords = stopwords.words('english')
lemma = nltk.wordnet.WordNetLemmatizer()

cleaner = udf(clean_description, StringType())

path = 'facebook-data'
facebook_files = [f for f in listdir(path) if isfile(join(path, f)) and (not f.startswith('.'))]

for facebook_file in facebook_files:
    print('Working on file: {}'.format(facebook_file))
    df = spark.read.json('facebook-data/{}'.format(facebook_file), schema=schema)
    fb_df = df.select(lower(col('fb_description')).alias('fb_description_lower'))
    fb_df_cleaned = fb_df.select(cleaner('fb_description_lower').alias('cleaned_description'))

    op_file_name = 'facebook-data/cleaned-ext/{}'.format(facebook_file)
    fb_df_cleaned.write.text(op_file_name)

# %%
from nltk.corpus import stopwords
# stopwords.stopwords('english')
stopwords.words('english')

# %% [markdown]
# Clean YouTube data

# %%
from pyspark.sql.types import StructField, StructType, StringType, ArrayType, IntegerType
from pyspark.sql.functions import lower, col, udf
from pyspark.sql import Row
from nltk.corpus import stopwords
import nltk
import pandas as pd
from os import listdir, makedirs
from os.path import isfile, join, exists
import json
import re

all_data = pd.read_csv('influencer_list.csv', sep=',')
print(all_data.shape)

sc = spark.sparkContext

def get_handle(url):
    splits = url.split('/')
    if url:
        if url.endswith('/'):
            handle = splits[-2]
        else:
            handle = splits[-1]
    else:
        handle = None    
    return handle


category_dict = dict()
for index, row in all_data.iterrows():
    handle = get_handle(row['Twitter'])
    category_dict[handle] = str(row['Category']).lower()


youtube_words = ['youtube', 'yt', 'https', 'http'] #Need to add more if required
fields = ['twitter_handle', 'video_id', 'likes', 'dislikes',
         'comments', 'views', 'title', 'description'
         'tags', 'publishat', 'cc_filename']

schema =  StructType([
    StructField('twitter_handle', StringType(), True),
    StructField('video_id', StringType(), True),
    StructField('likes', IntegerType(), True),
    StructField('dislikes', IntegerType(), True),
    StructField('comments', IntegerType(), True),
    StructField('views', IntegerType(), True),
    StructField('title', StringType(), True),
    StructField('description', StringType(), True),
    StructField('tags', ArrayType(StringType()), True),
    StructField('publishat', StringType(), True),
    StructField('cc_filename', StringType(), True),
])

def clean_cc(text):
    if text:
        cleaned = re.sub("(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", text).split()
        cleaned_ws = [word for word in cleaned if word not in stopwords and word not in facebook_words \
                     and word not in extended_stopwords]
        cleaned_wl = [lemma.lemmatize(word) for word in cleaned_ws]

        cleaned_wl = ' '.join(cleaned_ws) 
        return cleaned_wl.strip()
    else:
        return None
    
stopwords = stopwords.words('english')
lemma = nltk.wordnet.WordNetLemmatizer()

cleaner = udf(clean_description, StringType())

path = 'youtube-data'
youtube_files = [f for f in listdir(path) if isfile(join(path, f)) and (not f.startswith('.'))]

for youtube_file in youtube_files:
    print('Working on file: {}'.format(youtube_file))
    df = spark.read.json('youtube-data/{}'.format(youtube_file), schema=schema)
    cc_files = list(df.select('cc_filename').collect())
    category = category_dict[youtube_file]
    cc_path_prefix = '{}/others/{}/{}_cc/'.format(path, category, category)
    output_path_prefix = cc_path_prefix.replace(category + '_cc', category + '_cc_cleaned')
    output_directory = output_path_prefix + youtube_file + '/'
    if not exists(output_directory):
        makedirs(output_directory)
    for cc_file in cc_files:
        cc_name = cc_file['cc_filename']
        cc_file_path = cc_path_prefix + cc_name + '.txt'
        if exists(cc_file_path):
            cc_txt = sc.textFile(cc_file_path)
            cleaned_cc = cc_txt.map(clean_cc)
            output_path = output_directory + cc_name
            if not exists(output_path):
                cleaned_cc.saveAsTextFile(output_path)
            else:
                print("NOTICE-EXISTS;{}".format(output_path))

# %%
# Combine data into Single text file <Sources: Insta, FB, Twitter, FB>
# No cleaning
from pyspark.sql.types import StructField, StructType, StringType, ArrayType, IntegerType
from pyspark.sql.functions import lower, col, udf
from pyspark.sql import Row
from nltk.corpus import stopwords
import nltk
import pandas as pd
from os import listdir, makedirs
from os.path import isfile, join, exists
import json
import re

all_data = pd.read_csv('influencer_list.csv', sep=',')
print(all_data.shape)

# sc = spark.sparkContext

def get_handle(url):
    splits = url.split('/')
    if url:
        if url.endswith('/'):
            handle = splits[-2]
        else:
            handle = splits[-1]
    else:
        handle = None    
    return handle

tw_fields = ['screen_name', 'tweet_text', 'hashtags', 'favorites', 'retweet_count']
tw_schema =  StructType([
    StructField('screen_name', StringType(), True),
    StructField('tweet_text', StringType(), True),
    StructField('hashtags', ArrayType(StringType()), True),
    StructField('favorites', IntegerType(), True),
    StructField('retweet_count', IntegerType(), True),
])

ig_fields = ['twitter_handle', 'instagram_handle', 'likes', 'comments',
         'hashtags', 'caption', 'timestamp', 'image_thumbnail']

ig_schema =  StructType([
    StructField('twitter_handle', StringType(), True),
    StructField('instagram_handle', StringType(), True),
    StructField('likes', IntegerType(), True),
    StructField('comments', IntegerType(), True),
    StructField('hashtags', ArrayType(StringType()), True),
    StructField('caption', StringType(), True),
    StructField('timestamp', StringType(), True),
    StructField('image_thumbnail', StringType(), True),
])

fb_fields = ['twitter_handle', 'fb_handle', 'fb_name', 'fb_no_of_comments',
         'fb_time_created', 'fb_description', 'fb_post_link', 'fb_img_link'
         'fb_shares', 'fb_type']

fb_schema =  StructType([
    StructField('twitter_handle', StringType(), True),
    StructField('fb_handle', StringType(), True),
    StructField('fb_name', StringType(), True),
    StructField('fb_no_of_comments', IntegerType(), True),
    StructField('fb_time_created', StringType(), True),
    StructField('fb_description', StringType(), True),
    StructField('fb_post_link', StringType(), True),
    StructField('fb_img_link', StringType(), True),
    StructField('fb_shares', IntegerType(), True),
    StructField('fb_type', StringType(), True),
])

yt_fields = ['twitter_handle', 'video_id', 'likes', 'dislikes',
         'comments', 'views', 'title', 'description'
         'tags', 'publishat', 'cc_filename']

yt_schema =  StructType([
    StructField('twitter_handle', StringType(), True),
    StructField('video_id', StringType(), True),
    StructField('likes', IntegerType(), True),
    StructField('dislikes', IntegerType(), True),
    StructField('comments', IntegerType(), True),
    StructField('views', IntegerType(), True),
    StructField('title', StringType(), True),
    StructField('description', StringType(), True),
    StructField('tags', ArrayType(StringType()), True),
    StructField('publishat', StringType(), True),
    StructField('cc_filename', StringType(), True),
])

yt_path = 'youtube-data'
tw_path = 'twitter-data'
ig_path = 'instagram-data'
fb_path = 'facebook-data'

for index, row in all_data.iterrows():
    print(index, row)
# Out:
# (90, 6)
# 0 Influencer                                Kevin Curry
# Category                                         Food
# Twitter                https://twitter.com/fitmencook
# Facebook         https://www.facebook.com/FitMenCook/
# Instagram       https://www.instagram.com/FitMenCook/
# Youtube       https://www.youtube.com/user/fitmencook
# Name: 0, dtype: object
# 1 Influencer                                        Yolanda Gampp
# Category                                                   Food
# Twitter                    http://www.twitter.com/yolanda_gampp
# Facebook        https://www.facebook.com/HowToCakeItWithYolanda
# Instagram                    http://instagram.com/yolanda_gampp
# Youtube       https://www.youtube.com/channel/UCvM1hVcRJmVWD...
# Name: 1, dtype: object
# 2 Influencer                                     Izy Hossack
# Category                                              Food
# Twitter                  http://www.twitter.com/izyhossack
# Facebook             https://www.facebook.com/izy.hossack/
# Instagram             https://www.instagram.com/izyhossack
# Youtube       https://www.youtube.com/user/topwithcinnamon
# Name: 2, dtype: object
# 3 Influencer                                    Natasha Kravchuk
# Category                                                  Food
# Twitter                    https://twitter.com/NatashasKitchen
# Facebook             https://www.facebook.com/natashaskitchen/
# Instagram               https://instagram.com/natashaskitchen/
# Youtube       https://www.youtube.com/user/NatashasKitchenBlog
# Name: 3, dtype: object
# 4 Influencer                                     Ali Mafussi
# Category                                              Food
# Twitter                    http://twitter.com/inspiralized
# Facebook                  http://facebook.com/inspiralized
# Instagram                http://instagram.com/inspiralized
# Youtube       https://www.youtube.com/user/GetInspiralized
# Name: 4, dtype: object
# 5 Influencer                                Rosanna Pansino
# Category                                             Food
# Twitter                 http://twitter.com/rosannapansino
# Facebook               http://facebook.com/rosannapansino
# Instagram             http://instagram.com/rosannapansino
# Youtube       https://www.youtube.com/user/rosannapansino
# Name: 5, dtype: object
# 6 Influencer                              Deb Perelman
# Category                                        Food
# Twitter            http://twitter.com/smittenkitchen
# Facebook      http://www.facebook.com/smittenkitchen
# Instagram        http://instagram.com/smittenkitchen
# Youtube                                         null
# Name: 6, dtype: object
# 7 Influencer                                        Amber Spiegel
# Category                                                   Food
# Twitter                           https://twitter.com/sweetambs
# Facebook             https://www.facebook.com/SweetAmbsCookies/
# Instagram                  https://www.instagram.com/sweetambs/
# Youtube       https://www.youtube.com/channel/UC0L0iZDwLOizu...
# Name: 7, dtype: object
# 8 Influencer                                     Elise Strachan
# Category                                                 Food
# Twitter                   https://twitter.com/CupcakeAddictAU
# Facebook            https://www.facebook.com/cupcakeaddiction
# Instagram             http://instagram.com/mycupcakeaddiction
# Youtube       https://www.youtube.com/user/MyCupcakeaddiction
# Name: 8, dtype: object
# 9 Influencer                              Joy Wilson
# Category                                      Food
# Twitter            https://twitter.com/joythebaker
# Facebook      https://www.facebook.com/joythebaker
# Instagram         http://instagram.com/joythebaker
# Youtube                                       null
# Name: 9, dtype: object
# 10 Influencer                                Marques Brownlee
# Category                                        Technology
# Twitter                          https://twitter.com/MKBHD
# Facebook                   https://www.facebook.com/MKBHD/
# Instagram                  https://www.facebook.com/MKBHD/
# Youtube       https://www.youtube.com/user/marquesbrownlee
# Name: 10, dtype: object
# 11 Influencer                            Justine 'iJustine' Ezarik
# Category                                             Technology
# Twitter                            https://twitter.com/ijustine
# Facebook                     https://www.facebook.com/ijustine/
# Instagram                    https://www.instagram.com/ijustine
# Youtube       https://www.youtube.com/channel/UCey_c7U86mJGz...
# Name: 11, dtype: object
# 12 Influencer                            Lewis Hilsenteger
# Category                                     Technology
# Twitter                https://twitter.com/UnboxTherapy
# Facebook          https://www.facebook.com/unboxtherapy
# Instagram        https://www.instagram.com/unboxtherapy
# Youtube       https://www.youtube.com/user/unboxtherapy
# Name: 12, dtype: object
# 13 Influencer                                    Jonathan Morrison
# Category                                             Technology
# Twitter                            https://twitter.com/tldtoday
# Facebook                      https://www.facebook.com/tldtoday
# Instagram                    https://www.instagram.com/tldtoday
# Youtube       https://www.youtube.com/channel/UCDlQwv99CovKa...
# Name: 13, dtype: object
# 14 Influencer                               Linus Sebastian
# Category                                      Technology
# Twitter                    https://twitter.com/LinusTech
# Facebook       https://www.facebook.com/LinusGSebastian/
# Instagram            https://www.instagram.com/linustech
# Youtube       https://www.youtube.com/user/LinusTechTips
# Name: 14, dtype: object
# 15 Influencer                             Guy Kawasaki
# Category                                 Technology
# Twitter             https://twitter.com/GuyKawasaki
# Facebook               https://www.facebook.com/guy
# Instagram     https://www.instagram.com/guykawasaki
# Youtube                                        null
# Name: 15, dtype: object
# 16 Influencer                                         Austin Evans
# Category                                             Technology
# Twitter                     https://twitter.com/austinnotduncan
# Facebook               https://www.facebook.com/austinnotduncan
# Instagram             https://www.instagram.com/austinnotduncan
# Youtube       https://www.youtube.com/channel/UCXGgrKt94gR6l...
# Name: 16, dtype: object
# 17 Influencer                                Android Authority
# Category                                         Technology
# Twitter                     https://twitter.com/AndroidAuth
# Facebook          https://www.facebook.com/androidauthority
# Instagram        https://www.instagram.com/androidauthority
# Youtube       https://www.youtube.com/user/AndroidAuthority
# Name: 17, dtype: object
# 18 Influencer                                             Dave Lee
# Category                                             Technology
# Twitter                            https://twitter.com/Dave2Dtv
# Facebook               https://www.facebook.com/public/Dave-Lee
# Instagram                    https://www.instagram.com/dave2dtv
# Youtube       https://www.youtube.com/channel/UCVYamHliCI9rw...
# Name: 18, dtype: object
# 19 Influencer                              TechnoBuffalo
# Category                                   Technology
# Twitter             https://twitter.com/TechnoBuffalo
# Facebook       https://www.facebook.com/TechnoBuffalo
# Instagram     https://www.instagram.com/technobuffalo
# Youtube       https://www.youtube.com/user/jon4lakers
# Name: 19, dtype: object
# 20 Influencer                                      Chiara Ferragni
# Category                                                Fashion
# Twitter                      https://twitter.com/chiaraferragni
# Facebook                https://www.facebook.com/theblondesalad
# Instagram             https://www.instagram.com/chiaraferragni/
# Youtube       https://www.youtube.com/channel/UCuC1EZOes5x06...
# Name: 20, dtype: object
# 21 Influencer                                   Danielle Bernstein
# Category                                                Fashion
# Twitter                          https://twitter.com/weworewhat
# Facebook                   https://www.facebook.com/weworewhat/
# Instagram                 https://www.instagram.com/weworewhat/
# Youtube       https://www.youtube.com/channel/UCWRWLWUvCzGap...
# Name: 21, dtype: object
# 22 Influencer                                   Julia Engel
# Category                                         Fashion
# Twitter                 https://twitter.com/GalMeetsGlam
# Facebook          https://www.facebook.com/galmeetsglam/
# Instagram         https://www.instagram.com/juliahengel/
# Youtube       https://www.youtube.com/user/galmeetsglam/
# Name: 22, dtype: object
# 23 Influencer                                Gabi Gregg
# Category                                     Fashion
# Twitter                https://twitter.com/gabifresh
# Facebook         https://www.facebook.com/gabifresh/
# Instagram        https://www.instagram.com/gabifresh
# Youtube       https://www.youtube.com/user/gabifresh
# Name: 23, dtype: object
# 24 Influencer                                              Jenn Im
# Category                                                Fashion
# Twitter                            https://twitter.com/imjennim
# Facebook                      https://www.facebook.com/imjennim
# Instagram                    https://www.instagram.com/imjennim
# Youtube       https://www.youtube.com/channel/UCgWfS_47YPVbK...
# Name: 24, dtype: object
# 25 Influencer                                          Susanna Lau
# Category                                                Fashion
# Twitter                         https://twitter.com/susiebubble
# Facebook      https://www.facebook.com/Style-Bubble-14576667...
# Instagram                 https://www.instagram.com/susiebubble
# Youtube                https://www.youtube.com/user/susiebubble
# Name: 25, dtype: object
# 26 Influencer                                 Nicolette Mason
# Category                                           Fashion
# Twitter                 https://twitter.com/nicolettemason
# Facebook      https://www.facebook.com/NicoletteMasonBlog/
# Instagram         https://www.instagram.com/nicolettemason
# Youtube        https://www.youtube.com/user/nicolettesara/
# Name: 26, dtype: object
# 27 Influencer                                       Leandra Medine
# Category                                                Fashion
# Twitter                         https://twitter.com/ManRepeller
# Facebook                  https://www.facebook.com/manrepeller/
# Instagram               https://www.instagram.com/leandramcohen
# Youtube       https://www.youtube.com/channel/UCIp-X0aqvvKs8...
# Name: 27, dtype: object
# 28 Influencer                                      Aimee Song
# Category                                           Fashion
# Twitter                      https://twitter.com/aimeesong
# Facebook              https://www.facebook.com/SongOfStyle
# Instagram           https://www.instagram.com/songofstyle/
# Youtube       https://www.youtube.com/user/songofstyleblog
# Name: 28, dtype: object
# 29 Influencer                              Bryan Yambao
# Category                                     Fashion
# Twitter                 https://twitter.com/bryanboy
# Facebook           https://www.facebook.com/bryanboy
# Instagram     https://www.instagram.com/bryanboycom/
# Youtube                                         null
# Name: 29, dtype: object
# 30 Influencer                             Kate Albrecht
# Category                                        Home
# Twitter          http://www.twitter.com/mrkatedotcom
# Facebook        http://www.facebook.com/mrkatedotcom
# Instagram          https://www.instagram.com/mrkate/
# Youtube       https://www.youtube.com/user/TheMrkate
# Name: 30, dtype: object
# 31 Influencer                                 Grace Bonney
# Category                                           Home
# Twitter                https://twitter.com/designsponge
# Facebook          https://www.facebook.com/designsponge
# Instagram       https://www.instagram.com/designsponge/
# Youtube       https://www.youtube.com/user/designsponge
# Name: 31, dtype: object
# 32 Influencer                           Reichel Broussard
# Category                                          Home
# Twitter                https://twitter.com/copycatchic
# Facebook          https://www.facebook.com/copycatchic
# Instagram       https://www.instagram.com/copycatchic/
# Youtube       https://www.youtube.com/user/CopyCatChic
# Name: 32, dtype: object
# 33 Influencer                                     Paloma Contreras
# Category                                                   Home
# Twitter                     https://twitter.com/ladolcevitablog
# Facebook      http://facebook.com/La-Dolce-Vita-Blog-2971908...
# Instagram            http://instagram.com/palomacontrerasdesign
# Youtube                                                    null
# Name: 33, dtype: object
# 34 Influencer                                      Coco Cozy
# Category                                             Home
# Twitter                     https://twitter.com/cococozy/
# Facebook               https://www.facebook.com/cococozy/
# Instagram             https://www.instagram.com/cococozy/
# Youtube       https://www.youtube.com/user/cococozyvideo/
# Name: 34, dtype: object
# 35 Influencer                                           Bri Emery
# Category                                                  Home
# Twitter                  http://www.twitter.com/designlovefest
# Facebook                http://www.facebook.com/designlovefest
# Instagram                 http://instagram.com/designlovefest/
# Youtube       https://www.youtube.com/user/designlovefestvideo
# Name: 35, dtype: object
# 36 Influencer                                 Jennifer Hadfield
# Category                                                Home
# Twitter                      http://twitter.com/jenjentrixie
# Facebook           http://www.facebook.com/TatertotsandJello
# Instagram        https://www.instagram.com/tatertotsandjello
# Youtube       https://www.youtube.com/user/tatertotsandjello
# Name: 36, dtype: object
# 37 Influencer                                      Emily Henderson
# Category                                                   Home
# Twitter                        https://twitter.com/em_henderson
# Facebook         https://www.facebook.com/emilyhendersondesign/
# Instagram                   https://instagram.com/em_henderson/
# Youtube       https://www.youtube.com/channel/UC7Emkys9TIv4R...
# Name: 37, dtype: object
# 38 Influencer                                         Elsie Larson
# Category                                                   Home
# Twitter                      https://twitter.com/abeautifulmess
# Facebook      https://www.facebook.com/abeautifulmessbyelsie...
# Instagram                https://www.instagram.com/elsielarson/
# Youtube       https://www.youtube.com/channel/UCuwM3JPjY2tXa...
# Name: 38, dtype: object
# 39 Influencer                                  Will Taylor
# Category                                           Home
# Twitter                 http://twitter.com/brightbazaar
# Facebook               http://facebook.com/brightbazaar
# Instagram             http://instagram.com/brightbazaar
# Youtube       https://www.youtube.com/user/BrightBazaar
# Name: 39, dtype: object
# 40 Influencer                                       Rachel Brathen
# Category                                                Fitness
# Twitter                       https://twitter.com/RachelBrathen
# Facebook                  https://www.facebook.com/rachelsyoga/
# Instagram                   https://www.instagram.com/yoga_girl
# Youtube       https://www.youtube.com/channel/UCExTOE3jupt24...
# Name: 40, dtype: object
# 41 Influencer                                  Cassey Ho
# Category                                      Fitness
# Twitter                https://twitter.com/blogilates
# Facebook          https://www.facebook.com/blogilates
# Instagram        https://www.instagram.com/blogilates
# Youtube       https://www.youtube.com/user/blogilates
# Name: 41, dtype: object
# 42 Influencer                                Kayla Itsines
# Category                                        Fitness
# Twitter               https://twitter.com/kayla_itsines
# Facebook             https://www.facebook.com/k.itsines
# Instagram       https://www.instagram.com/kayla_itsines
# Youtube       https://www.youtube.com/user/kaylaitsines
# Name: 42, dtype: object
# 43 Influencer                                       Natalie Jill
# Category                                              Fitness
# Twitter                    https://twitter.com/nataliejillfit
# Facebook              https://www.facebook.com/nataliejillfit
# Instagram            https://www.instagram.com/nataliejillfit
# Youtube       https://www.youtube.com/user/nataliejillfitness
# Name: 43, dtype: object
# 44 Influencer                                       Michelle Lewin
# Category                                                Fitness
# Twitter                      https://twitter.com/michelle_lewin
# Facebook               https://www.facebook.com/FitnessMichelle
# Instagram              https://www.instagram.com/michelle_lewin
# Youtube       https://www.youtube.com/channel/UCXOF8RQ_v52K1...
# Name: 44, dtype: object
# 45 Influencer                                   Lyzabeth Lopez
# Category                                            Fitness
# Twitter                   https://twitter.com/LyzabethLopez
# Facebook      https://www.facebook.com/lyzabethlopezfitness
# Instagram           https://www.instagram.com/lyzabethlopez
# Youtube          https://www.youtube.com/user/LyzabethLopez
# Name: 45, dtype: object
# 46 Influencer                                         Simeon Panda
# Category                                                Fitness
# Twitter                         https://twitter.com/SimeonPanda
# Facebook                  https://www.facebook.com/simeonpanda/
# Instagram                 https://www.instagram.com/simeonpanda
# Youtube       https://www.youtube.com/channel/UC_Ih0f1H_eyHe...
# Name: 46, dtype: object
# 47 Influencer                                      Jennifer Selter
# Category                                                Fitness
# Twitter                           https://twitter.com/JenSelter
# Facebook                    https://www.facebook.com/jenLselter
# Instagram                   https://www.instagram.com/jenselter
# Youtube       https://www.youtube.com/channel/UCQ5PReLqxPs9G...
# Name: 47, dtype: object
# 48 Influencer                                  Emily Skye
# Category                                       Fitness
# Twitter              https://twitter.com/missemilyskye
# Facebook      https://www.facebook.com/emilyskyemodel/
# Instagram       https://www.instagram.com/emilyskyefit
# Youtube             https://www.youtube.com/EmilySkye/
# Name: 48, dtype: object
# 49 Influencer                                            Joe Wicks
# Category                                                Fitness
# Twitter                https://twitter.com/hashtag/thebodycoach
# Facebook          https://www.facebook.com/JoeWicksTheBodyCoach
# Instagram                https://www.instagram.com/thebodycoach
# Youtube       https://www.youtube.com/channel/UCAxW1XT0iEJo0...
# Name: 49, dtype: object
# 50 Influencer                                         Damon and Jo
# Category                                                 Travel
# Twitter                          https://twitter.com/damonandjo
# Facebook                   https://www.facebook.com/DamonAndJo/
# Instagram                 https://www.instagram.com/damonandjo/
# Youtube       https://www.youtube.com/channel/UCASjTz4wC5E-8...
# Name: 50, dtype: object
# 51 Influencer                                   Johnny Jet
# Category                                         Travel
# Twitter                   https://twitter.com/JohnnyJet
# Facebook         https://www.facebook.com/JohnnyJet747/
# Instagram           https://www.instagram.com/johnnyjet
# Youtube       https://www.youtube.com/user/johnnyjet747
# Name: 51, dtype: object
# 52 Influencer                                         The Planet D
# Category                                                 Travel
# Twitter                          https://twitter.com/theplanetd
# Facebook                   https://www.facebook.com/ThePlanetD/
# Instagram                 https://www.instagram.com/theplanetd/
# Youtube       https://www.youtube.com/channel/UCVBD2a1uUkhX1...
# Name: 52, dtype: object
# 53 Influencer                                        Chris Burkard
# Category                                                 Travel
# Twitter                        https://twitter.com/chrisburkard
# Facebook       https://www.facebook.com/ChrisBurkardPhotography
# Instagram               https://www.instagram.com/chrisburkard/
# Youtube       https://www.youtube.com/channel/UCX8a9aGMdL9aa...
# Name: 53, dtype: object
# 54 Influencer                                  Louis Cole
# Category                                        Travel
# Twitter                https://twitter.com/funforlouis
# Facebook          https://www.facebook.com/FunForLouis
# Instagram       https://www.instagram.com/funforlouis/
# Youtube       https://www.youtube.com/user/FunForLouis
# Name: 54, dtype: object
# 55 Influencer                                  Brian Kelly
# Category                                         Travel
# Twitter               https://twitter.com/thepointsguy/
# Facebook         https://www.facebook.com/thepointsguy/
# Instagram       https://www.instagram.com/thepointsguy/
# Youtube       https://www.youtube.com/user/ThePointsGuy
# Name: 55, dtype: object
# 56 Influencer                                   Kate McCulley
# Category                                            Travel
# Twitter                https://twitter.com/adventurouskate
# Facebook         https://www.facebook.com/AdventurousKate/
# Instagram       https://www.instagram.com/adventurouskate/
# Youtube       https://www.youtube.com/user/adventurouskate
# Name: 56, dtype: object
# 57 Influencer                              Murad and Nataly Osmann
# Category                                                 Travel
# Twitter                         https://twitter.com/MuradOsmann
# Facebook              https://www.facebook.com/followmeproject/
# Instagram                  https://www.instagram.com/followmeto
# Youtube       https://www.youtube.com/channel/UCWx2TJ0pg2Lyx...
# Name: 57, dtype: object
# 58 Influencer                                        Kiersten Rich
# Category                                                 Travel
# Twitter                     https://twitter.com/theblondeabroad
# Facebook               https://www.facebook.com/theblondeabroad
# Instagram            https://www.instagram.com/theblondeabroad/
# Youtube       https://www.youtube.com/channel/UCv-fxyco4Z6DU...
# Name: 58, dtype: object
# 59 Influencer                                Eric Stoen
# Category                                      Travel
# Twitter              https://twitter.com/TravelBabbo
# Facebook        https://www.facebook.com/travelbabbo
# Instagram     https://www.instagram.com/travelbabbo/
# Youtube                                         null
# Name: 59, dtype: object
# 60 Influencer                                          Lilly Singh
# Category                                          Entertainment
# Twitter                      https://twitter.com/iisuperwomanii
# Facebook                https://www.facebook.com/IISuperwomanII
# Instagram             https://www.instagram.com/iisuperwomanii/
# Youtube       https://www.youtube.com/channel/UCfm4y4rHF5HGr...
# Name: 60, dtype: object
# 61 Influencer                                      King Bach
# Category                                    Entertainment
# Twitter                      https://twitter.com/kingbach
# Facebook                https://www.facebook.com/KingBach
# Instagram             https://www.instagram.com/kingbach/
# Youtube       https://www.youtube.com/user/BachelorsPadTv
# Name: 61, dtype: object
# 62 Influencer                                       Cameron Dallas
# Category                                          Entertainment
# Twitter                       https://twitter.com/camerondallas
# Facebook                 https://www.facebook.com/camerondallas
# Instagram              https://www.instagram.com/camerondallas/
# Youtube       https://www.youtube.com/channel/UCUKxWDTKylMaL...
# Name: 62, dtype: object
# 63 Influencer                                Shane Dawson
# Category                                 Entertainment
# Twitter                https://twitter.com/shanedawson
# Facebook      https://www.facebook.com/shanedawsonfans
# Instagram       https://www.instagram.com/shanedawson/
# Youtube             https://www.youtube.com/user/shane
# Name: 63, dtype: object
# 64 Influencer                                          Hannah Hart
# Category                                          Entertainment
# Twitter                               https://twitter.com/harto
# Facebook            https://www.facebook.com/HannahHartOfficial
# Instagram                      https://www.instagram.com/harto/
# Youtube       https://www.youtube.com/channel/UCJQL1Fai-9GlV...
# Name: 64, dtype: object
# 65 Influencer                                         Ariel Martin
# Category                                          Entertainment
# Twitter                           https://twitter.com/BabyAriel
# Facebook            https://www.facebook.com/OfficialBabyAriel/
# Instagram                  https://www.instagram.com/babyariel/
# Youtube       https://www.youtube.com/channel/UCrv1Jwqqo_Xc7...
# Name: 65, dtype: object
# 66 Influencer                                        Miranda Sings
# Category                                          Entertainment
# Twitter                        https://twitter.com/MirandaSings
# Facebook         https://www.facebook.com/MirandaSingsOfficial/
# Instagram        https://www.instagram.com/mirandasingsofficial
# Youtube       https://www.youtube.com/channel/UC1OFDlfdRb6ma...
# Name: 66, dtype: object
# 67 Influencer                                Tyler Oakley
# Category                                 Entertainment
# Twitter                https://twitter.com/tyleroakley
# Facebook       https://www.facebook.com/thetyleroakley
# Instagram       https://www.instagram.com/tyleroakley/
# Youtube       https://www.youtube.com/user/tyleroakley
# Name: 67, dtype: object
# 68 Influencer                                           Logan Paul
# Category                                          Entertainment
# Twitter                           https://twitter.com/loganpaul
# Facebook                     https://www.facebook.com/LoganPaul
# Instagram                  https://www.instagram.com/loganpaul/
# Youtube       https://www.youtube.com/channel/UCG8rbF3g2AMX7...
# Name: 68, dtype: object
# 69 Influencer                                            Lele Pons
# Category                                          Entertainment
# Twitter                            https://twitter.com/lelepons
# Facebook                          https://www.facebook.com/lele
# Instagram                   https://www.instagram.com/lelepons/
# Youtube       https://www.youtube.com/channel/UCi9cDo6239RAz...
# Name: 69, dtype: object
# 70 Influencer                                               DanTDM
# Category                                                 Gaming
# Twitter                              https://twitter.com/dantdm
# Facebook            https://www.facebook.com/TheDiamondMinecart
# Instagram                      https://www.instagram.com/dantdm
# Youtube       https://www.youtube.com/channel/UCS5Oz6CHmeoF7...
# Name: 70, dtype: object
# 71 Influencer                                        Jacksepticeye
# Category                                                 Gaming
# Twitter                     https://twitter.com/Jack_Septic_Eye
# Facebook         https://www.facebook.com/officialjacksepticeye
# Instagram               https://www.instagram.com/jacksepticeye
# Youtube       https://www.youtube.com/channel/UCYzPXprvl5Y-S...
# Name: 71, dtype: object
# 72 Influencer                                 PewDiePie
# Category                                      Gaming
# Twitter                https://twitter.com/pewdiepie
# Facebook          https://www.facebook.com/PewDiePie
# Instagram        https://www.instagram.com/pewdiepie
# Youtube       https://www.youtube.com/user/PewDiePie
# Name: 72, dtype: object
# 73 Influencer                                     SkyDoesMinecraft
# Category                                                 Gaming
# Twitter                     https://twitter.com/skydoesawesomes
# Facebook          https://www.facebook.com/realskydoesminecraft
# Instagram                                                  null
# Youtube       https://www.youtube.com/channel/UCY61yCeQBRZ38...
# Name: 73, dtype: object
# 74 Influencer                                         SSSniperWolf
# Category                                                 Gaming
# Twitter                        https://twitter.com/sssniperwolf
# Facebook                  https://www.facebook.com/SSSniperWolf
# Instagram                https://www.instagram.com/sssniperwolf
# Youtube       https://www.youtube.com/channel/UCpB959t8iPrxQ...
# Name: 74, dtype: object
# 75 Influencer                                 TheSyndicateProject
# Category                                                Gaming
# Twitter                       https://twitter.com/ProSyndicate
# Facebook         https://www.facebook.com/TheSyndicateProject/
# Instagram        https://www.instagram.com/thesyndicateproject
# Youtube       https://www.youtube.com/user/TheSyndicateProject
# Name: 75, dtype: object
# 76 Influencer                                         VanossGaming
# Category                                                 Gaming
# Twitter                        https://twitter.com/VanossGaming
# Facebook                  https://www.facebook.com/VanossGaming
# Instagram                                                  null
# Youtube       https://www.youtube.com/channel/UCKqH_9mk1waLg...
# Name: 76, dtype: object
# 77 Influencer                                           Markiplier
# Category                                                 Gaming
# Twitter                          https://twitter.com/markiplier
# Facebook                    https://www.facebook.com/markiplier
# Instagram              https://www.instagram.com/markipliergram
# Youtube       https://www.youtube.com/channel/UC7_YxT-KID8kR...
# Name: 77, dtype: object
# 78 Influencer                                           Sonja Reid
# Category                                                 Gaming
# Twitter                      https://twitter.com/OMGitsfirefoxx
# Facebook                 https://www.facebook.com/sonja.reid123
# Instagram              https://www.instagram.com/omgitsfirefoxx
# Youtube       https://www.youtube.com/channel/UCKi52SDIwr5ys...
# Name: 78, dtype: object
# 79 Influencer                                   Mari Takahashi
# Category                                             Gaming
# Twitter                   https://twitter.com/takahashimari
# Facebook      https://www.facebook.com/peaceloveandinternet
# Instagram              https://www.instagram.com/atomicmari
# Youtube             https://www.youtube.com/user/ATOMICMARI
# Name: 79, dtype: object
# 80 Influencer                              Nikkie de Jager
# Category                                         Beauty
# Twitter             https://twitter.com/nikkietutorials
# Facebook        http://www.facebook.com/nikkietutorials
# Instagram     https://www.instagram.com/nikkietutorials
# Youtube         https://www.youtube.com/nikkietutorials
# Name: 80, dtype: object
# 81 Influencer                                Christen Dominique
# Category                                              Beauty
# Twitter                  https://twitter.com/christendtweets
# Facebook        https://www.facebook.com/dominiquecosmetics/
# Instagram      https://www.instagram.com/dominiquecosmetics/
# Youtube       https://www.youtube.com/user/christendominique
# Name: 81, dtype: object
# 82 Influencer                                           Wayne Goss
# Category                                                 Beauty
# Twitter                           http://twitter.com/beautylish
# Facebook                         http://facebook.com/beautylish
# Instagram                       http://instagram.com/beautylish
# Youtube       https://www.youtube.com/channel/UCCvoAe__WFYMN...
# Name: 82, dtype: object
# 83 Influencer                                      Manny Gutierrez
# Category                                                 Beauty
# Twitter                         https://twitter.com/mannymua733
# Facebook                    http://www.facebook.com/MannyMua733
# Instagram                 https://www.instagram.com/mannymua733
# Youtube       https://www.youtube.com/channel/UCbO9bltbkYwa5...
# Name: 83, dtype: object
# 84 Influencer                                       Shannon Harris
# Category                                                 Beauty
# Twitter                            https://twitter.com/xoShaaan
# Facebook              https://www.facebook.com/ShaaanxoYouTube/
# Instagram                    https://www.instagram.com/shaaanxo
# Youtube       https://www.youtube.com/channel/UCMpOz2KEfkSdd...
# Name: 84, dtype: object
# 85 Influencer                                Kandee Johnson
# Category                                          Beauty
# Twitter                https://twitter.com/kandeejohnson
# Facebook           http://www.facebook.com/kandeejohnson
# Instagram        https://www.instagram.com/kandeejohnson
# Youtube       https://www.youtube.com/user/kandeejohnson
# Name: 85, dtype: object
# 86 Influencer                                          Huda Kattan
# Category                                                 Beauty
# Twitter                          https://twitter.com/hudabeauty
# Facebook                   https://www.facebook.com/hudabeauty/
# Instagram                   http://www.instagram.com/hudabeauty
# Youtube       https://www.youtube.com/channel/UCRSvEADlY-caz...
# Name: 86, dtype: object
# 87 Influencer                                        Michelle Phan
# Category                                                 Beauty
# Twitter                     http://www.twitter.com/michellephan
# Facebook           http://www.facebook.com/MichellePhanOfficial
# Instagram                 http://www.instagram.com/michellephan
# Youtube       http://www.youtube.com/channel/UCuYx81nzzz4OFQ...
# Name: 87, dtype: object
# 88 Influencer                                         Jeffree Star
# Category                                                 Beauty
# Twitter                         https://twitter.com/JeffreeStar
# Facebook                  https://www.facebook.com/JeffreeStar/
# Instagram                 https://www.instagram.com/jeffreestar
# Youtube       https://www.youtube.com/channel/UCkvK_5omS-42O...
# Name: 88, dtype: object
# 89 Influencer                                    Zoe Sugg
# Category                                        Beauty
# Twitter                  http://www.twitter.com/zoella
# Facebook            http://www.facebook.com/zoe.zoella
# Instagram              http://www.instagram.com/zoella
# Youtube       http://www.youtube.com/user/zoella280390
# Name: 89, dtype: object
